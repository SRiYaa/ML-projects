# %%
import pandas as pd
df=pd.read_csv("C:/Datasets/gapminder.csv")

# %%
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0       2.73  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0       6.43  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0       2.24  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0       1.40  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0       1.96  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
y=df["fertility"]

# %%
x=df.drop("fertility",axis =1)

# %%
x.head()
# Out:
#    population  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
x.isna().sum()
# Out:
# population         0
# HIV                0
# CO2                0
# BMI_male           0
# GDP                0
# BMI_female         0
# life               0
# child_mortality    0
# Region             0
# dtype: int64

# %%
y.isna().sum()
# Out:
# 0

# %%
x.dtypes
# Out:
# population         float64
# HIV                float64
# CO2                float64
# BMI_male           float64
# GDP                float64
# BMI_female         float64
# life               float64
# child_mortality    float64
# Region              object
# dtype: object

# %%
#not all are numeric
pd.get_dummies(x,columns=["Region"])  #one hot encoding
# Out:
#      population   HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0    34811059.0   0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1    19842251.0   2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2    40381860.0   0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3     2975029.0   0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4    21370348.0   0.1  18.016313  27.56373  41312.0    117.3755  81.5
# ..          ...   ...        ...       ...      ...         ...   ...
# 134   3350832.0   0.5   2.489764  26.39123  15317.0    124.2604  76.0
# 135  26952719.0   0.1   4.476669  25.32054   3733.0    124.3462  68.7
# 136  86589342.0   0.4   1.479347  20.91630   4085.0    121.9367  75.4
# 137  13114579.0  13.6   0.148982  20.68321   3039.0    132.4493  52.0
# 138  13495462.0  15.1   0.654323  22.02660   1286.0    131.9745  49.0
#
#      child_mortality  Region_America  Region_East Asia & Pacific  \
# ...

# %%
x["Region"].unique()
# Out:
# array(['Middle East & North Africa', 'Sub-Saharan Africa', 'America',
#        'Europe & Central Asia', 'East Asia & Pacific', 'South Asia'],
#       dtype=object)

# %%
#dummy encoding (drop one region)
pd.get_dummies(x,columns=["Region"],drop_first=True)
# Out:
#      population   HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0    34811059.0   0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1    19842251.0   2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2    40381860.0   0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3     2975029.0   0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4    21370348.0   0.1  18.016313  27.56373  41312.0    117.3755  81.5
# ..          ...   ...        ...       ...      ...         ...   ...
# 134   3350832.0   0.5   2.489764  26.39123  15317.0    124.2604  76.0
# 135  26952719.0   0.1   4.476669  25.32054   3733.0    124.3462  68.7
# 136  86589342.0   0.4   1.479347  20.91630   4085.0    121.9367  75.4
# 137  13114579.0  13.6   0.148982  20.68321   3039.0    132.4493  52.0
# 138  13495462.0  15.1   0.654323  22.02660   1286.0    131.9745  49.0
#
#      child_mortality  Region_East Asia & Pacific  \
# 0               29.5                           0
# ...

# %%
x= pd.get_dummies(x,columns=["Region"],drop_first=True)

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.shape
# Out:
# (139, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
x.describe()
# Out:
#          population         HIV         CO2    BMI_male            GDP  \
# count  1.390000e+02  139.000000  139.000000  139.000000     139.000000
# mean   3.549977e+07    1.915612    4.459874   24.623054   16638.784173
# std    1.095121e+08    4.408974    6.268349    2.209368   19207.299083
# min    2.773150e+05    0.060000    0.008618   20.397420     588.000000
# 25%    3.752776e+06    0.100000    0.496190   22.448135    2899.000000
# 50%    9.705130e+06    0.400000    2.223796   25.156990    9938.000000
# 75%    2.791973e+07    1.300000    6.589156   26.497575   23278.500000
# max    1.197070e+09   25.900000   48.702062   28.456980  126076.000000
#
#        BMI_female        life  child_mortality  Region_East Asia & Pacific  \
# count  139.000000  139.000000       139.000000                  139.000000
# mean   126.701914   69.602878        45.097122                    0.100719
# std      4.471997    9.122189        45.724667                    0.302045
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_train= scaler.fit_transform(x_train)
x_test= scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.880326468970407

# %%
#prediction
data=pd.DataFrame({"First":[100],"Second":[0.7],"Third":[55],"Fourth":[30],"Fifth":[12000],"Sixth":[200],"Seventh":[70],"Eighth":[130],"Ninth":[0],"Tenth":[0],"Eleventh":[0],"Twelve":[1],"Thirteen":[0]})

# %%
data.shape
# Out:
# (1, 13)

# %%
data
# Out:
#    First  Second  Third  Fourth  Fifth  Sixth  Seventh  Eighth  Ninth  Tenth  \
# 0    100     0.7     55      30  12000    200       70     130      0      0
#
#    Eleventh  Twelve  Thirteen
# 0         0       1         0

# %%
data= scaler.transform(data)

# %%
model.predict(data)
# Out:
# array([-0.49384071])

# %%
#from sklearn.tree import DecisionTreeRegressor
#model= DecisionTreeRegressor()
#model.fit(x_train,y_train)
#model.score(x_test,y_test)
#model.score(x_train,y_train) // again overfitting

#or change

#model= DecisionTreeRegressor(min_sample_leaf=5)
